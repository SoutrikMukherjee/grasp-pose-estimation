# %% [markdown]
# # 6-DOF Grasp Pose Estimation from Point Clouds
#
# **Author**: Soutrik Mukherjee
# **Objective**: Build a PointNet-based deep learning model for robotic grasp pose estimation
#
# ## Project Overview
# This notebook demonstrates end-to-end development of a production-ready grasp estimation system:
# - Point cloud processing and augmentation
# - PointNet architecture implementation in PyTorch
# - 6-DOF pose regression (position + orientation + quality)
# - Real-time inference optimization
# - ROS 2 integration template
#
# ---

# %%
# Import libraries
import numpy as np
import torch
import torch.nn as nn
from scipy.spatial.transform import Rotation as R
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

print('Libraries imported successfully')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
